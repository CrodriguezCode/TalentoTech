# %% [markdown]
# <a href="https://colab.research.google.com/github/CrodriguezCode/TalentoTech/blob/main/carlosrodriguez_practical_example_during_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejemplos prácticos durante la clase

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Datos
x = [1,2,2,3,4,4,5,6] # Valores de x
y = [2,3,4,4,4,6,5,7] # Valores de y


datos = {"x":x,
         "y":y}

df = pd.DataFrame(datos)
df
# Out:
#    x  y
# 0  1  2
# 1  2  3
# 2  2  4
# 3  3  4
# 4  4  4
# 5  4  6
# 6  5  5
# 7  6  7

# %%
df['xy'] = df['x']*df['y']
df
# Out:
#    x  y  xy
# 0  1  2   2
# 1  2  3   6
# 2  2  4   8
# 3  3  4  12
# 4  4  4  16
# 5  4  6  24
# 6  5  5  25
# 7  6  7  42

# %%
df['x^2'] = df['x']**2
df
# Out:
#    x  y  xy  x^2
# 0  1  2   2    1
# 1  2  3   6    4
# 2  2  4   8    4
# 3  3  4  12    9
# 4  4  4  16   16
# 5  4  6  24   16
# 6  5  5  25   25
# 7  6  7  42   36

# %%
sum_x = df['x'].sum()
sum_y = df['y'].sum()
sum_xy = df['xy'].sum()
sum_x2 = df['x^2'].sum()
prom_x = df['x'].mean()
prom_y = df['y'].mean()
print(sum_x, sum_y, sum_xy, sum_x2)
# Out:
# 27 35 135 111

# %%
n = df.shape[0]  # numero de filas
print(n)
# Out:
# 8

# %%
m=(n*sum_xy-sum_x*sum_y)/(n*sum_x2-sum_x**2)
b=prom_y-m*prom_x
print(m,b)
# Out:
# 0.8490566037735849 1.5094339622641506

# %%
plt.scatter(df['x'], df['y'],color='red')
plt.plot(df['x'], m*df['x']+b)
plt.show()

# %%
df['s_i'] = (df['y']-(m*df['x']+b))**2
df
# Out:
#    x  y  xy  x^2       s_i
# 0  1  2   2    1  0.128515
# 1  2  3   6    4  0.043076
# 2  2  4   8    4  0.627981
# 3  3  4  12    9  0.003204
# 4  4  4  16   16  0.820221
# 5  4  6  24   16  1.197579
# 6  5  5  25   25  0.569598
# 7  6  7  42   36  0.156995

# %%
sr = df['s_i'].sum()
print(sr)
# Out:
# 3.5471698113207544

# %%
e_lineal=sr**0.5 / n
print(e_lineal)
# Out:
# 0.23542414553712793

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset
# Let´s build the values lists
value_elemento_list = ["Cerio", "Galio", "Litio", "Osmio", "Prometio", "Rutenio", "Selenio", "Talio", "Tecnecio", "Vanadio"] # nombre del atomo
#print(value_n_list)

value_simbolo_list = ["Ce", "Ga", "Li", "Os", "Pm", "Ru", "Se", "Tl", "Tc", "V"] # simbolo
value_pesoatomico_list = [140.12, 69.72, 6.94, 190.23, 147, 101.07, 78.96, 204.39, 98, 50.94] # [uma]
value_radioatomico_list =   [236, 136, 167, 166, 184, 175, 115, 170, 183, 134] # [pm]
value_numeroprotones_list =   [58, 31, 3, 76, 54, 44, 34, 81, 43, 23] # Numero de protones
value_numeroatomico_list =   [58, 31, 3, 76, 54, 44, 34, 81, 43, 23] # Numero Atomico
value_estadovalecia_list = [1, 3, 1, 8, 2, 8, 6, 1, 7, 5]
value_estadonatural_list = ["Metal de transición", "Metal pobre", "Metal alcalino", "Metal de transición", "Metal de transición radiactivo", "Metal de transición", "No metal", "Metal pesado", "Metal de transición radiactivo", "Metal de transición"]


# Let´s use a dictionary ({key:value})
# with the format {"str":list}
#data_dict = {"nombre":value_n_list,
#              "largo":value_largo_list,
#             "ancho":value_ancho_list,
#             "alto":value_alto_list}
data_dict = {"elemento(e)":value_elemento_list,
             "simbolo(s)":value_simbolo_list,
             "peso_atomico(pa)":value_pesoatomico_list,
             "radio_atomico(ra)":value_radioatomico_list,
             "numero_protones(np)":value_numeroprotones_list,
             "numero_atomico(na)":value_numeroatomico_list,
             "estado_valecia(ev)":value_estadovalecia_list,
             "estado_natural(en)":value_estadonatural_list}


#print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

#print(df)
# Call a variable
df
# Out:
#   elemento(e) simbolo(s)  peso_atomico(pa)  radio_atomico(ra)  \
# 0       Cerio         Ce            140.12                236
# 1       Galio         Ga             69.72                136
# 2       Litio         Li              6.94                167
# 3       Osmio         Os            190.23                166
# 4    Prometio         Pm            147.00                184
# 5     Rutenio         Ru            101.07                175
# 6     Selenio         Se             78.96                115
# 7       Talio         Tl            204.39                170
# 8    Tecnecio         Tc             98.00                183
# 9     Vanadio          V             50.94                134
#
#    numero_protones(np)  numero_atomico(na)  estado_valecia(ev)  \
# 0                   58                  58                   1
# 1                   31                  31                   3
# 2                    3                   3                   1
# ...

# %%
# prompt: Con DataFrame df: add another column

df['pa/ra'] = df['peso_atomico(pa)']/df['radio_atomico(ra)']
df
# Out:
#   elemento(e) simbolo(s)  peso_atomico(pa)  radio_atomico(ra)  \
# 0       Cerio         Ce            140.12                236
# 1       Galio         Ga             69.72                136
# 2       Litio         Li              6.94                167
# 3       Osmio         Os            190.23                166
# 4    Prometio         Pm            147.00                184
# 5     Rutenio         Ru            101.07                175
# 6     Selenio         Se             78.96                115
# 7       Talio         Tl            204.39                170
# 8    Tecnecio         Tc             98.00                183
# 9     Vanadio          V             50.94                134
#
#    numero_protones(np)  numero_atomico(na)  estado_valecia(ev)  \
# 0                   58                  58                   1
# 1                   31                  31                   3
# 2                    3                   3                   1
# ...

# %%
df['pa/np'] = df['peso_atomico(pa)']/df['numero_protones(np)']
df
# Out:
#   elemento(e) simbolo(s)  peso_atomico(pa)  radio_atomico(ra)  \
# 0       Cerio         Ce            140.12                236
# 1       Galio         Ga             69.72                136
# 2       Litio         Li              6.94                167
# 3       Osmio         Os            190.23                166
# 4    Prometio         Pm            147.00                184
# 5     Rutenio         Ru            101.07                175
# 6     Selenio         Se             78.96                115
# 7       Talio         Tl            204.39                170
# 8    Tecnecio         Tc             98.00                183
# 9     Vanadio          V             50.94                134
#
#    numero_protones(np)  numero_atomico(na)  estado_valecia(ev)  \
# 0                   58                  58                   1
# 1                   31                  31                   3
# 2                    3                   3                   1
# ...

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns # Import seaborn for heatmap plotting

# ... (rest of your code remains the same)

# Calculate the correlation matrix, excluding non-numeric columns
correlation_matrix = df.select_dtypes(include=['number']).corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#                      peso_atomico(pa)  radio_atomico(ra)  numero_protones(np)  \
# peso_atomico(pa)             1.000000           0.398502             0.994987
# radio_atomico(ra)            0.398502           1.000000             0.392906
# numero_protones(np)          0.994987           0.392906             1.000000
# numero_atomico(na)           0.994987           0.392906             1.000000
# estado_valecia(ev)           0.019865          -0.314868             0.072656
#
#                      numero_atomico(na)  estado_valecia(ev)
# peso_atomico(pa)               0.994987            0.019865
# radio_atomico(ra)              0.392906           -0.314868
# numero_protones(np)            1.000000            0.072656
# numero_atomico(na)             1.000000            0.072656
# estado_valecia(ev)             0.072656            1.000000

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset
# Let´s build the values lists
value_n_list = ['Gran_Pirámide_de_Giza', 'Pirámide de Kefrén', 'Pirámide de Micerino', "Pirámide Roja", "Pirámide Acodada", "Pirámide Escalonada de Zoser", "Pirámide de Chichén Itzá", "Templo de Kukulcán", "Pirámide de los Nichos", "Pirámide de Calakmul"] # [str
print(value_n_list)

value_largo_list = [230.33,215.25,108.8,105,101,125,55,55,40,55] # [m]
value_ancho_list = [230.38,215.5,108.6,105,87,109,55,55,40,45] # [m]
value_alto_list =   [138.8, 136.4, 67.75, 104.7, 95.5, 60, 30, 30, 30, 28] # [m]

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
#data_dict = {"nombre":value_n_list,
#              "largo":value_largo_list,
#             "ancho":value_ancho_list,
#             "alto":value_alto_list}
data_dict = {"largo":value_largo_list,
             "ancho":value_ancho_list,
             "alto":value_alto_list}


#print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

#print(df)
# Call a variable
df
# Out:
# ['Gran_Pirámide_de_Giza', 'Pirámide de Kefrén', 'Pirámide de Micerino', 'Pirámide Roja', 'Pirámide Acodada', 'Pirámide Escalonada de Zoser', 'Pirámide de Chichén Itzá', 'Templo de Kukulcán', 'Pirámide de los Nichos', 'Pirámide de Calakmul']
#     largo   ancho    alto
# 0  230.33  230.38  138.80
# 1  215.25  215.50  136.40
# 2  108.80  108.60   67.75
# 3  105.00  105.00  104.70
# 4  101.00   87.00   95.50
# 5  125.00  109.00   60.00
# 6   55.00   55.00   30.00
# 7   55.00   55.00   30.00
# 8   40.00   40.00   30.00
# 9   55.00   45.00   28.00

# %%
# prompt: Con DataFrame df: add another column

df['volumen'] = df['largo']*df['alto']*df['ancho']/ 3
df
# Out:
#     largo   ancho    alto       volumen
# 0  230.33  230.38  138.80  2.455068e+06
# 1  215.25  215.50  136.40  2.109034e+06
# 2  108.80  108.60   67.75  2.668374e+05
# 3  105.00  105.00  104.70  3.847725e+05
# 4  101.00   87.00   95.50  2.797195e+05
# 5  125.00  109.00   60.00  2.725000e+05
# 6   55.00   55.00   30.00  3.025000e+04
# 7   55.00   55.00   30.00  3.025000e+04
# 8   40.00   40.00   30.00  1.600000e+04
# 9   55.00   45.00   28.00  2.310000e+04

# %%
# prompt: Con DataFrame df: add another column
import math
df['long_incl_1'] = np.sqrt((df['largo']/2)**2 + df['alto']**2)
df
# Out:
#     largo   ancho    alto       volumen  long_incl_1
# 0  230.33  230.38  138.80  2.455068e+06   180.356362
# 1  215.25  215.50  136.40  2.109034e+06   173.747232
# 2  108.80  108.60   67.75  2.668374e+05    86.887413
# 3  105.00  105.00  104.70  3.847725e+05   117.125318
# 4  101.00   87.00   95.50  2.797195e+05   108.030088
# 5  125.00  109.00   60.00  2.725000e+05    86.638617
# 6   55.00   55.00   30.00  3.025000e+04    40.697051
# 7   55.00   55.00   30.00  3.025000e+04    40.697051
# 8   40.00   40.00   30.00  1.600000e+04    36.055513
# 9   55.00   45.00   28.00  2.310000e+04    39.246019

# %%
# prompt: Con DataFrame df: add another column
import math
df['long_incl_2'] = np.sqrt((df['ancho']/2)**2 + df['alto']**2)
df
# Out:
#     largo   ancho    alto       volumen  long_incl_1  long_incl_2
# 0  230.33  230.38  138.80  2.455068e+06   180.356362   180.372326
# 1  215.25  215.50  136.40  2.109034e+06   173.747232   173.824689
# 2  108.80  108.60   67.75  2.668374e+05    86.887413    86.824838
# 3  105.00  105.00  104.70  3.847725e+05   117.125318   117.125318
# 4  101.00   87.00   95.50  2.797195e+05   108.030088   104.940459
# 5  125.00  109.00   60.00  2.725000e+05    86.638617    81.057079
# 6   55.00   55.00   30.00  3.025000e+04    40.697051    40.697051
# 7   55.00   55.00   30.00  3.025000e+04    40.697051    40.697051
# 8   40.00   40.00   30.00  1.600000e+04    36.055513    36.055513
# 9   55.00   45.00   28.00  2.310000e+04    39.246019    35.920050

# %%
# prompt: Con DataFrame df: add another column
import math
df['dif_long'] = df['long_incl_1'] - df['long_incl_2']
df
# Out:
#     largo   ancho    alto       volumen  long_incl_1  long_incl_2  dif_long
# 0  230.33  230.38  138.80  2.455068e+06   180.356362   180.372326 -0.015965
# 1  215.25  215.50  136.40  2.109034e+06   173.747232   173.824689 -0.077457
# 2  108.80  108.60   67.75  2.668374e+05    86.887413    86.824838  0.062575
# 3  105.00  105.00  104.70  3.847725e+05   117.125318   117.125318  0.000000
# 4  101.00   87.00   95.50  2.797195e+05   108.030088   104.940459  3.089629
# 5  125.00  109.00   60.00  2.725000e+05    86.638617    81.057079  5.581539
# 6   55.00   55.00   30.00  3.025000e+04    40.697051    40.697051  0.000000
# 7   55.00   55.00   30.00  3.025000e+04    40.697051    40.697051  0.000000
# 8   40.00   40.00   30.00  1.600000e+04    36.055513    36.055513  0.000000
# 9   55.00   45.00   28.00  2.310000e+04    39.246019    35.920050  3.325969

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#                 largo     ancho      alto   volumen  long_incl_1  long_incl_2  \
# largo        1.000000  0.995266  0.914969  0.950893     0.962640     0.960379
# ancho        0.995266  1.000000  0.913096  0.964378     0.959127     0.960378
# alto         0.914969  0.913096  1.000000  0.857155     0.989993     0.990535
# volumen      0.950893  0.964378  0.857155  1.000000     0.904810     0.909702
# long_incl_1  0.962640  0.959127  0.989993  0.904810     1.000000     0.999321
# long_incl_2  0.960379  0.960378  0.990535  0.909702     0.999321     1.000000
# dif_long    -0.102843 -0.196449 -0.182689 -0.284895    -0.151621    -0.187948
#
#              dif_long
# largo       -0.102843
# ancho       -0.196449
# alto        -0.182689
# volumen     -0.284895
# long_incl_1 -0.151621
# long_incl_2 -0.187948
# dif_long     1.000000

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset
# Let´s build the values lists
value_n_list = ['Andrew', 'Phillip', 'John', "Maria", "Carlos", "Alicia", "Danilo", "Cristian", "Juan", "Roberto"] # [str
print(value_n_list)

value_w_list = [50,         78,      91.5,    60,   70,   80,   55,   65,   72,  88] # [kg]
value_h_list = [1.76,      1.87,     1.69,    1.65,   1.96,   1.55,   1.66,   1.54,   1.69,   1.63] # [m]
# value_bmi_list will be calculated: bmi = w/(h^2)
#value_bmi_list = [25,25,25] # init values [kg/m2]

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
data_dict = {#"name":value_n_list,
             "weight":value_w_list,
             "height":value_h_list} #,
              #"BMI":value_bmi_list}

print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)
# Call a variable
df
# Out:
# ['Andrew', 'Phillip', 'John', 'Maria', 'Carlos', 'Alicia', 'Danilo', 'Cristian', 'Juan', 'Roberto']
# {'weight': [50, 78, 91.5, 60, 70, 80, 55, 65, 72, 88], 'height': [1.76, 1.87, 1.69, 1.65, 1.96, 1.55, 1.66, 1.54, 1.69, 1.63]}
#    weight  height
# 0    50.0    1.76
# 1    78.0    1.87
# 2    91.5    1.69
# 3    60.0    1.65
# 4    70.0    1.96
# 5    80.0    1.55
# 6    55.0    1.66
# 7    65.0    1.54
# 8    72.0    1.69
# 9    88.0    1.63
#    weight  height
# 0    50.0    1.76
# 1    78.0    1.87
# 2    91.5    1.69
# 3    60.0    1.65
# 4    70.0    1.96
# 5    80.0    1.55
# 6    55.0    1.66
# 7    65.0    1.54
# 8    72.0    1.69
# 9    88.0    1.63

# %%
# prompt: Con DataFrame df: add another column

df['bmi'] = df['weight'] / (df['height'] ** 2)
df
# Out:
#    weight  height        bmi
# 0    50.0    1.76  16.141529
# 1    78.0    1.87  22.305471
# 2    91.5    1.69  32.036693
# 3    60.0    1.65  22.038567
# 4    70.0    1.96  18.221574
# 5    80.0    1.55  33.298647
# 6    55.0    1.66  19.959355
# 7    65.0    1.54  27.407657
# 8    72.0    1.69  25.209201
# 9    88.0    1.63  33.121307

# %%
df.describe()
# Out:
#          weight     height        bmi
# count  10.00000  10.000000  10.000000
# mean   70.95000   1.700000  24.974000
# std    13.72437   0.132246   6.289588
# min    50.00000   1.540000  16.141529
# 25%    61.25000   1.635000  20.479158
# 50%    71.00000   1.675000  23.757336
# 75%    79.50000   1.742500  30.879434
# max    91.50000   1.960000  33.298647

# %% [markdown]
# ## Making some transformations on the df

# %%
# z = x / y*y
df["BMI"] =  df["weight"] / df["height"]**2
df
# Out:
#    weight  height        bmi        BMI
# 0    50.0    1.76  16.141529  16.141529
# 1    78.0    1.87  22.305471  22.305471
# 2    91.5    1.69  32.036693  32.036693
# 3    60.0    1.65  22.038567  22.038567
# 4    70.0    1.96  18.221574  18.221574
# 5    80.0    1.55  33.298647  33.298647
# 6    55.0    1.66  19.959355  19.959355
# 7    65.0    1.54  27.407657  27.407657
# 8    72.0    1.69  25.209201  25.209201
# 9    88.0    1.63  33.121307  33.121307

# %% [markdown]
# De acuerdo a los resultados puede conlcuir que:
#
# -El valor max es:
# -

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Import the seaborn module and give it the alias 'sns'
import seaborn as sns

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#           weight    height       bmi       BMI
# weight  1.000000 -0.057239  0.810831  0.810831
# height -0.057239  1.000000 -0.624270 -0.624270
# bmi     0.810831 -0.624270  1.000000  1.000000
# BMI     0.810831 -0.624270  1.000000  1.000000

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#           weight    height       bmi       BMI
# weight  1.000000 -0.057239  0.810831  0.810831
# height -0.057239  1.000000 -0.624270 -0.624270
# bmi     0.810831 -0.624270  1.000000  1.000000
# BMI     0.810831 -0.624270  1.000000  1.000000

# %%
df["BMI"].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BMI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# TO-DO: create another column with integers and turn it to float, such as:
df["BMI"] = df["BMI"].astype(float)

# %%
df["BMI"].dtype
# Out:
# dtype('float64')

# %%
df["name"].dtype
# Homework: how to verify that a column contains string
# Out:
# dtype('O')

# %%
df
# Out:
#       name  weight  height        bmi        BMI
# 0   Andrew    50.0    1.76  16.141529  16.141529
# 1  Phillip    78.0    1.87  22.305471  22.305471
# 2     John    91.5    1.69  32.036693  32.036693

# %% [markdown]
# ## Init steps towards EDA (Exploratory Data Analisys):
#  Homework: perform a full EDA with your own invented dataset with at least 10 rows

# %%
# Descriptive stats
df_stats = df.describe()
df_stats
# Out:
#           weight    height        bmi        BMI
# count   3.000000  3.000000   3.000000   3.000000
# mean   73.166667  1.773333  23.494564  23.494564
# std    21.167979  0.090738   8.014020   8.014020
# min    50.000000  1.690000  16.141529  16.141529
# 25%    64.000000  1.725000  19.223500  19.223500
# 50%    78.000000  1.760000  22.305471  22.305471
# 75%    84.750000  1.815000  27.171082  27.171082
# max    91.500000  1.870000  32.036693  32.036693

# %% [markdown]
# ### TO-DO: please analyze the results (univariate: describe() / multivariate: correlation matrix)

# %%
#df["health_condition"] = 'within the normal range' if 18.0<=df['BMI']<=25.0 else 'out of the normal range'
#df

# %% [markdown]
# # Prompt used in chat GPT (by OpenAI) / Gemini (by Google) / Bing (Copilot by Microsoft) to solve the above error:
#
# You are a python expert, please help with the error I will show later that is appearing when I run this code in Google collab: "df["health_condition"] = 'within the normal range' if 18.0<=df['BMI']<=25.0 else 'out of the normal range'".
#
# The error is:
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4e9a74b99b6c> in <cell line: 1>()
# ----> 1 df["health_condition"] = 'within the normal range' if 18.0<=df['BMI']<=25.0 else 'out of the normal range'
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#       name  weight  height        bmi        BMI
# 0   Andrew    50.0    1.76  16.141529  16.141529
# 1  Phillip    78.0    1.87  22.305471  22.305471
# 2     John    91.5    1.69  32.036693  32.036693

# %%
print(df)
# Out:
#       name  weight  height        bmi        BMI
# 0   Andrew    50.0    1.76  16.141529  16.141529
# 1  Phillip    78.0    1.87  22.305471  22.305471
# 2     John    91.5    1.69  32.036693  32.036693

# %%
df_stats
# Out:
#           weight    height        bmi        BMI
# count   3.000000  3.000000   3.000000   3.000000
# mean   73.166667  1.773333  23.494564  23.494564
# std    21.167979  0.090738   8.014020   8.014020
# min    50.000000  1.690000  16.141529  16.141529
# 25%    64.000000  1.725000  19.223500  19.223500
# 50%    78.000000  1.760000  22.305471  22.305471
# 75%    84.750000  1.815000  27.171082  27.171082
# max    91.500000  1.870000  32.036693  32.036693

# %%
print(df_stats)
# Out:
#           weight    height        bmi        BMI
# count   3.000000  3.000000   3.000000   3.000000
# mean   73.166667  1.773333  23.494564  23.494564
# std    21.167979  0.090738   8.014020   8.014020
# min    50.000000  1.690000  16.141529  16.141529
# 25%    64.000000  1.725000  19.223500  19.223500
# 50%    78.000000  1.760000  22.305471  22.305471
# 75%    84.750000  1.815000  27.171082  27.171082
# max    91.500000  1.870000  32.036693  32.036693

# %%
df["health_condition"] = np.where(  (df['BMI'] >= 18.0) & (df['BMI'] <= 25.0) , 'within the normal range', 'out of the normal range' )
df
# Out:
#       name  weight  height        bmi        BMI         health_condition
# 0   Andrew    50.0    1.76  16.141529  16.141529  out of the normal range
# 1  Phillip    78.0    1.87  22.305471  22.305471  within the normal range
# 2     John    91.5    1.69  32.036693  32.036693  out of the normal range

# %%
# Define a function to determine health condition
def determine_health_condition(bmi):
    if 18.0 <= bmi <= 25.0:
        return 'within the normal range'
    else:
        return 'out of the normal range'

# Apply the function to create the new column
df["health_condition4"] = df["BMI"].apply(determine_health_condition)

# %%
print(df)
df
# Out:
#       name  weight  height        bmi        BMI         health_condition  \
# 0   Andrew    50.0    1.76  16.141529  16.141529  out of the normal range
# 1  Phillip    78.0    1.87  22.305471  22.305471  within the normal range
# 2     John    91.5    1.69  32.036693  32.036693  out of the normal range
#
#          health_condition4
# 0  out of the normal range
# 1  within the normal range
# 2  out of the normal range
#       name  weight  height        bmi        BMI         health_condition  \
# 0   Andrew    50.0    1.76  16.141529  16.141529  out of the normal range
# 1  Phillip    78.0    1.87  22.305471  22.305471  within the normal range
# 2     John    91.5    1.69  32.036693  32.036693  out of the normal range
#
#          health_condition4
# 0  out of the normal range
# 1  within the normal range
# 2  out of the normal range

# %%
# Define a function to determine health condition
def determine_health_condition7(bmi):
    """
    if 18.0 <= bmi <= 25.0:
        return 'within the normal range'
    else:
        return 'out of the normal range'
    """
    return 'within the normal range' if 18.0 <= bmi <= 25.0 else 'out of the normal range'

# Apply the function to create the new column
df["health_condition6"] = df["BMI"].apply(determine_health_condition7)
df
# Out:
#       name  weight  height        bmi        BMI         health_condition  \
# 0   Andrew    50.0    1.76  16.141529  16.141529  out of the normal range
# 1  Phillip    78.0    1.87  22.305471  22.305471  within the normal range
# 2     John    91.5    1.69  32.036693  32.036693  out of the normal range
#
#          health_condition4        health_condition6
# 0  out of the normal range  out of the normal range
# 1  within the normal range  within the normal range
# 2  out of the normal range  out of the normal range

# %% [markdown]
# #### Please remove the unnecessary columns and search how to upload/download the df as .csv and .json and .xlsx

# %% [markdown]
# # Correlation matrix (9-jul-2024)
#
# ChatGPT prompt used:
#
# "you´re a python expert, please give code to get the correlation matrix of a dataframe with a simple example and calculus explanation"

# %%
 # Simple example given by chat GPT
import pandas as pd

# Create a sample DataFrame
data = {
    'A': [1, 2, 3, 4],
    'B': [4, 3, 2, 1],
    'C': [2, 4, 6, 8],
}

df = pd.DataFrame(data)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#      A    B    C
# A  1.0 -1.0  1.0
# B -1.0  1.0 -1.0
# C  1.0 -1.0  1.0

# %% [markdown]
# # A more complete example with synthetic data given by ChatGPT

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)  # for reproducibility

data = {
    'A': np.random.randn(100),
    'B': np.random.randn(100) * 2,
    'C': np.random.randn(100) + 1,
    'D': np.random.randn(100) - 1,
}

df = pd.DataFrame(data)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#           A         B         C         D
# A  1.000000 -0.136422  0.190840 -0.170227
# B -0.136422  1.000000 -0.036632 -0.017613
# C  0.190840 -0.036632  1.000000 -0.000259
# D -0.170227 -0.017613 -0.000259  1.000000

# %%
data
# Out:
# {'A': array([ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337,
#         -0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004,
#         -0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783,
#         -0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ,
#          1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272,
#          0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375,
#         -0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491,
#         -1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124,
#          0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199,
#         -0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016,
#          0.32408397, -0.38508228, -0.676922  ,  0.61167629,  1.03099952,
#          0.93128012, -0.83921752, -0.30921238,  0.33126343,  0.97554513,
#         -0.47917424, -0.18565898, -1.10633497, -1.19620662,  0.81252582,
# ...

# %%
df
# Out:
#            A         B         C         D
# 0   0.496714 -2.830741  1.357787 -1.828995
# 1  -0.138264 -0.841291  1.560785 -1.560181
# 2   0.647689 -0.685429  2.083051 -0.252706
# 3   1.523030 -1.604555  2.053802 -0.389630
# 4  -0.234153 -0.322571 -0.377669 -1.020902
# ..       ...       ...       ...       ...
# 95 -1.463515  0.770635  0.307090 -1.469176
# 96  0.296120 -1.767715  1.899600 -2.713135
# 97  0.261055  0.307450  1.307300  0.353872
# 98  0.005113  0.116417  1.812862 -1.114540
# 99 -0.234587 -2.285941  1.629629  0.237816
#
# [100 rows x 4 columns]

# %% [markdown]
# # Consultar cómo es el cálculo de la matriz de correlación (PEND):

# %% [markdown]
# La matriz de correlación es una herramienta fundamental en el análisis estadístico, permitiendo evaluar la relación lineal entre pares de variables en un conjunto de datos. Su cálculo se basa en los conceptos de covarianza y correlación lineal, los cuales se definen a continuación:
#
# Covarianza:
#
# La covarianza (Cov) entre dos variables X e Y representa la variación conjunta de ambas. Se calcula como la media de los productos de sus desviaciones respecto a sus medias:
#
# Cov(X, Y) = Σ[(xi - X̄)(yi - Ȳ)] / n
# Donde:
#
# n es el tamaño de la muestra
# xi y yi son los valores individuales de las variables X e Y, respectivamente
# X̄ y Ȳ son las medias de las variables X e Y, respectivamente
# Correlación lineal:
#
# El coeficiente de correlación lineal (ρ) entre dos variables X e Y mide la fuerza y dirección de su relación lineal. Se obtiene dividiendo la covarianza entre el producto de sus desviaciones estándar:
#
# ρ(X, Y) = Cov(X, Y) / [σx * σy]
# Donde:
#
# σx y σy son las desviaciones estándar de las variables X e Y, respectivamente
# Cálculo de la matriz de correlación:
#
# La matriz de correlación R es una matriz cuadrada de n x n dimensiones, donde cada elemento Rij representa el coeficiente de correlación lineal entre las variables Xi y Xj:
#
# R = [ ρ(X1, X1) ρ(X1, X2) ... ρ(X1, Xn) ]
#     [ ρ(X2, X1) ρ(X2, X2) ... ρ(X2, Xn) ]
#     [ ...         ...         ...  ]
#     [ ρ(Xn, X1) ρ(Xn, X2) ... ρ(Xn, Xn) ]
# El cálculo de la matriz de correlación implica determinar cada elemento Rij utilizando la fórmula de correlación lineal mencionada anteriormente. Para ello, se requieren las medias, desviaciones estándar y covarianzas de todas las variables del conjunto de datos.
#
# Interpretación de la matriz de correlación:
#
# Los valores de la matriz de correlación oscilan entre -1 y 1. Un valor de 1 indica una correlación lineal positiva perfecta, mientras que un valor de -1 indica una correlación lineal negativa perfecta. Un valor de 0 indica que no existe correlación lineal entre las variables.
#
# En general, valores absolutos cercanos a 1 (ya sean positivos o negativos) sugieren una fuerte relación lineal entre las variables. Sin embargo, es importante tener en cuenta que la correlación no implica causalidad. Es decir, el hecho de que dos variables estén correlacionadas no significa necesariamente que una cause la otra.
#
# Ejemplo:
#
# Supongamos que tenemos un conjunto de datos con las variables Edad (en años), Altura (en cm) y Peso (en kg) de 10 individuos. Para calcular la matriz de correlación, se deben seguir estos pasos:
#
# Calcular la media, desviación estándar y covarianza de cada variable.
# Utilizar la fórmula de correlación lineal para obtener el coeficiente de correlación entre cada par de variables.
# Completar la matriz de correlación con los coeficientes de correlación obtenidos.
# Consideraciones adicionales:
#
# El cálculo manual de la matriz de correlación puede ser tedioso y propenso a errores para conjuntos de datos grandes. Se recomienda utilizar software estadístico como Excel, SPSS o R para realizar estos cálculos de manera eficiente.
# La matriz de correlación es una herramienta útil para explorar las relaciones entre variables en un conjunto de datos. Sin embargo, es importante complementarla con otros análisis estadísticos para obtener una comprensión completa de los datos.
# Incluir formulas como si estuvieran escritas en un tablero

# %% [markdown]
# # Tarea: consultar qué es y cómo funciona la matriz de confusión (clasificación)

# %% [markdown]
# La matriz de confusión: Una herramienta fundamental para evaluar modelos de clasificación
# En el ámbito del aprendizaje automático, la matriz de confusión se erige como una herramienta fundamental para evaluar el rendimiento de un modelo de clasificación. Esta tabla nos permite visualizar de manera detallada cómo se distribuyen las predicciones del modelo en comparación con las etiquetas reales de los datos.
#
# ¿Cómo se compone una matriz de confusión?
#
# Imaginemos un escenario de clasificación binaria, donde tenemos dos clases: "Positivo" y "Negativo". La matriz de confusión para este caso se estructura de la siguiente manera:
#
# Positivo real	Negativo real
# Positivo predicho	Verdaderos positivos (VP)	Falsos positivos (FP)
# Negativo predicho	Falsos negativos (FN)	Verdaderos negativos (VN)
#
# drive_spreadsheet
# Export to Sheets
# Verdaderos positivos (VP): Representa la cantidad de instancias que fueron correctamente clasificadas como "Positivo" tanto por el modelo como por la etiqueta real.
# Falsos positivos (FP): Indica la cantidad de instancias que el modelo clasificó erróneamente como "Positivo", cuando en realidad son "Negativo".
# Falsos negativos (FN): Representa la cantidad de instancias que el modelo clasificó erróneamente como "Negativo", cuando en realidad son "Positivo".
# Verdaderos negativos (VN): Indica la cantidad de instancias que fueron correctamente clasificadas como "Negativo" tanto por el modelo como por la etiqueta real.
# ¿Cómo interpretar la matriz de confusión?
#
# A partir de los valores presentes en la matriz de confusión, podemos calcular diversas métricas que nos brindan información valiosa sobre el desempeño del modelo:
#
# Precisión: Mide la proporción de instancias que el modelo clasificó correctamente como "Positivo" entre todas las que predijo como "Positivo". Se calcula como: Precisión = VP / (VP + FP).
# Sensibilidad: Indica la proporción de instancias "Positivas" que el modelo identificó correctamente. Se calcula como: Sensibilidad = VP / (VP + FN).
# Especificidad: Mide la proporción de instancias "Negativas" que el modelo clasificó correctamente. Se calcula como: Especificidad = VN / (VN + FP).
# Exactitud: Representa la proporción de instancias totales que el modelo clasificó correctamente. Se calcula como: Exactitud = (VP + VN) / (VP + VN + FP + FN).
# ¿Cómo funciona la matriz de confusión?
#
# La matriz de confusión funciona como una tabla de contingencia que resume los resultados de las predicciones del modelo en comparación con las etiquetas reales. Al analizarla, podemos identificar los tipos de errores que el modelo comete con mayor frecuencia, lo que nos permite tomar decisiones informadas para mejorar su rendimiento.
#
# Ejemplo práctico:
#
# Supongamos que tenemos un modelo de clasificación de correos electrónicos como "spam" o "no spam". La matriz de confusión para este caso podría ser:
#
# Spam real	No spam real
# Spam predicho	40	10
# No spam predicho	5	195
#
# drive_spreadsheet
# Export to Sheets
# En este ejemplo, el modelo tiene una precisión del 80% (40 VP / (40 VP + 10 FP)), una sensibilidad del 89% (40 VP / (40 VP + 5 FN)) y una especificidad del 95% (195 VN / (195 VN + 10 FP)).
#
# Sin embargo, observamos que el modelo comete 10 errores de clasificación de "no spam" como "spam" (FP), lo que podría indicar que el modelo es demasiado sensible a ciertas características que no siempre son distintivas de correos electrónicos no deseados.
#
# Conclusión:
#
# La matriz de confusión se convierte en una herramienta invaluable para evaluar el rendimiento de modelos de clasificación, ya que nos permite visualizar de forma detallada los aciertos y errores del modelo, identificar los tipos de errores más comunes y tomar decisiones informadas para optimizar su desempeño.
#
# Recursos adicionales:
#
# Cómo interpretar la matriz de confusión: ejemplo práctico: https://www.researchgate.net/figure/Figura-3-Matriz-de-Confusion-promedio-obtenida-empleando-los-estadisticos-media_fig3_271764921
# La matriz de confusión y sus métricas: https://www.juanbarrios.com/la-matriz-de-confusion-y-sus-metricas/
# Aprovechando el rendimiento de la matriz de confusión: https://datascience.recursos.uoc.edu/es/matrices-de-confusion/

# %% [markdown]
# # Consultar las métricas de desempeño para regresión y clasificación

# %% [markdown]
# Las métricas de desempeño son herramientas esenciales para evaluar el rendimiento de un modelo de aprendizaje automático. Ayudan a determinar qué tan bien el modelo predice los valores correctos o clasifica las instancias correctamente. La elección de la métrica adecuada depende del tipo de problema que se está abordando, ya sea un problema de regresión o de clasificación.
#
#
# **Métricas de regresión:**
#
# Las métricas de regresión evalúan la precisión de las predicciones continuas. Algunas de las métricas de regresión más comunes son:
#
# **Error cuadrático medio (MSE):** Mide la diferencia promedio al cuadrado entre los valores predichos y los valores reales. Un MSE más bajo indica un mejor rendimiento del modelo.
#
# **Raíz del error cuadrático medio (RMSE):** Es la raíz cuadrada del MSE. Representa la desviación estándar de las predicciones del valor real. Un RMSE más bajo indica un mejor rendimiento del modelo.
#
#
#
# **Error absoluto medio (MAE):** Mide la diferencia promedio absoluta entre los valores predichos y los valores reales. Un MAE más bajo indica un mejor rendimiento del modelo.
#
#
# **Coeficiente de determinación (R^2):** Mide la proporción de la varianza total en los datos que es explicada por el modelo. Un R^2 más alto indica un mejor ajuste del modelo a los datos.
#
#
# # Métricas de clasificación:
#
# Las métricas de clasificación evalúan la precisión de las predicciones categóricas. Algunas de las métricas de clasificación más comunes son:
#
# **Matriz de confusión:** Una tabla que muestra el número de instancias correctamente clasificadas e incorrectamente clasificadas.
# Opens in a new window
# medium.com
# Confusion matrix metric
#
# **Exactitud:** La proporción de instancias correctamente clasificadas en total.
#
# **Precisión:** La proporción de instancias positivas predichas que son realmente positivas.
#
# **Sensibilidad (Recall):** La proporción de instancias positivas reales que son correctamente identificadas como positivas.
#
# **Puntaje F1:** La media armónica de la precisión y la sensibilidad.
# Curva ROC (Receiver Operating Characteristic): Una gráfica que muestra la tasa de verdaderos positivos (TPR) frente a la tasa de falsos positivos (FPR) a diferentes umbrales de clasificación.
#
# **Área bajo la curva ROC (AUC):** Una medida del rendimiento general del clasificador independientemente del umbral de clasificación. Un AUC más alto indica un mejor rendimiento del modelo.
#
# **Selección de la métrica adecuada:**
#
# La elección de la métrica adecuada depende de varios factores, como el tipo de problema, la importancia de diferentes tipos de errores y la disponibilidad de datos. Es importante considerar cuidadosamente estos factores al seleccionar una métrica para evaluar el rendimiento de su modelo.
#
# Recursos adicionales:
#
# https://upcommons.upc.edu/bitstream/handle/2117/327755/memoria.pdf
# https://www.geeksforgeeks.org/confusion-matrix-machine-learning/
# https://www.unipiloto.edu.co/
