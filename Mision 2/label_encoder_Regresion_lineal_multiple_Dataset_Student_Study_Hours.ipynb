# %% [markdown]
# <a href="https://colab.research.google.com/github/CrodriguezCode/TalentoTech/blob/main/label_encoder_Regresion_lineal_multiple_Dataset_Student_Study_Hours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando datos

# %%
#este dataset lo obtuve de https://www.kaggle.com/datasets/nikhil7280/student-performance-multiple-linear-regression

import pandas as pd
import sklearn
import seaborn as sns

df_studyhours = pd.read_csv("Student_Performance.csv")
df_studyhours
# Out:
#       Hours_Studied  Previous_Scores Extracurricular_Activities  Sleep_Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample_Question_Papers_Practiced  Performance_Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...                                ...                ...
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64
#
# [10000 rows x 6 columns]

# %%
df_studyhours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours_Studied                     10000 non-null  int64
#  1   Previous_Scores                   10000 non-null  int64
#  2   Extracurricular_Activities        10000 non-null  object
#  3   Sleep_Hours                       10000 non-null  int64
#  4   Sample_Question_Papers_Practiced  10000 non-null  int64
#  5   Performance_Index                 10000 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 468.9+ KB

# %% [markdown]
# # Codificando datos object a int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_studyhours['Extracurricular_Activities_Bin'] = le.fit_transform(df_studyhours['Extracurricular_Activities'])
df_studyhours
# Out:
#       Hours_Studied  Previous_Scores Extracurricular_Activities  Sleep_Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample_Question_Papers_Practiced  Performance_Index  \
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...                                ...                ...
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64
#
#       Extracurricular_Activities_Bin
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 9995                               1
# 9996                               1
# 9997                               1
# 9998                               1
# 9999                               0
#
# [10000 rows x 7 columns]

# %%
df_studyhours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours_Studied                     10000 non-null  int64
#  1   Previous_Scores                   10000 non-null  int64
#  2   Extracurricular_Activities        10000 non-null  object
#  3   Sleep_Hours                       10000 non-null  int64
#  4   Sample_Question_Papers_Practiced  10000 non-null  int64
#  5   Performance_Index                 10000 non-null  int64
#  6   Extracurricular_Activities_Bin    10000 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 547.0+ KB

# %% [markdown]
# #Eliminando columna object

# %%
df_studyhours=df_studyhours.drop(columns=['Extracurricular_Activities'])
df_studyhours
# Out:
#       Hours_Studied  Previous_Scores  Sleep_Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample_Question_Papers_Practiced  Performance_Index  \
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...                                ...                ...
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64
#
#       Extracurricular_Activities_Bin
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 9995                               1
# 9996                               1
# 9997                               1
# 9998                               1
# 9999                               0
#
# [10000 rows x 6 columns]

# %%
df_studyhours.describe()
# Out:
#        Hours_Studied  Previous_Scores   Sleep_Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample_Question_Papers_Practiced  Performance_Index  \
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000
#
#        Extracurricular_Activities_Bin
# count                    10000.000000
# mean                         0.494800
# std                          0.499998
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          1.000000
# max                          1.000000

# %% [markdown]
# #Matriz de Correlacion

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns # Import seaborn for heatmap plotting

# Calculate the correlation matrix, excluding non-numeric columns
# Assuming 'Study_Hours' is the numerical column you want to analyze
correlation_matrix = df_studyhours.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#                                   Hours_Studied  Previous_Scores  Sleep_Hours  \
# Hours_Studied                          1.000000        -0.012390     0.001245
# Previous_Scores                       -0.012390         1.000000     0.005944
# Sleep_Hours                            0.001245         0.005944     1.000000
# Sample_Question_Papers_Practiced       0.017463         0.007888     0.003990
# Performance_Index                      0.373730         0.915189     0.048106
# Extracurricular_Activities_Bin         0.003873         0.008369    -0.023284
#
#                                   Sample_Question_Papers_Practiced  \
# Hours_Studied                                             0.017463
# Previous_Scores                                           0.007888
# Sleep_Hours                                               0.003990
# Sample_Question_Papers_Practiced                          1.000000
# Performance_Index                                         0.043268
# Extracurricular_Activities_Bin                            0.013103
#
#                                   Performance_Index  \
# Hours_Studied                              0.373730
# Previous_Scores                            0.915189
# Sleep_Hours                                0.048106
# Sample_Question_Papers_Practiced           0.043268
# Performance_Index                          1.000000
# Extracurricular_Activities_Bin             0.024525
#
#                                   Extracurricular_Activities_Bin
# Hours_Studied                                           0.003873
# Previous_Scores                                         0.008369
# Sleep_Hours                                            -0.023284
# Sample_Question_Papers_Practiced                        0.013103
# Performance_Index                                       0.024525
# Extracurricular_Activities_Bin                          1.000000

# %%
#sns.jointplot(x="Hours", y="Scores", data=df_studyhours)

# %% [markdown]
# # 2.2 Preparando los datos y realizando modelo de regresión lineal
# Particionando el dataset para la creación de modelos. Esto mediante la función `train_test_split` de scikit-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# extrayendo la información del dataset
X = df_studyhours[["Hours_Studied","Previous_Scores","Sleep_Hours","Sample_Question_Papers_Practiced","Extracurricular_Activities_Bin"]] # Reshape to 2D array, use a list for multiple columns
y = df_studyhours["Performance_Index"]

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# crear el modelo
regressor = LinearRegression(fit_intercept = True)

# entrenarlo con los datos
regressor.fit(X_train, y_train)  # Now x_train is a 2D array

# el modelo tendrá dos parámetros (A y B fueron llamados en el documento)
# se pueden mostrar con la función print
print(f"La pendiente del modelo (B) es: {regressor.coef_}, el intersecto (A) es {regressor.intercept_}")
# Out:
# La pendiente del modelo (B) es: [2.84905292 1.01782609 0.48178222 0.19017075 0.63234957], el intersecto (A) es -34.01528307767633

# %% [markdown]
# # Realizando metricas del resultado de la regresion

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# Realizar predicciones en el conjunto de prueba
y_pred = regressor.predict(X_test)
print("Mean Squared Error:",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test, y_pred)))
print("Mean Absolute Error:",mean_absolute_error(y_test, y_pred))
print("R^2:",r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 4.206564358473631
# Root Mean Squared Error: 2.0509910673802634
# Mean Absolute Error: 1.6219584957551645
# R^2: 0.9887010608185887
# Mean Absolute Percentage Error: 0.03419484670458523

# %%
import matplotlib.pyplot as plt
error = y_test-y_pred
plt.hist(error)
# Out:
# (array([ 15.,  88., 256., 584., 744., 501., 234.,  65.,  11.,   2.]),
#  array([-6.62321422, -5.12421586, -3.62521751, -2.12621915, -0.62722079,
#          0.87177757,  2.37077593,  3.86977428,  5.36877264,  6.867771  ,
#          8.36676936]),
#  <BarContainer object of 10 artists>)

# %%
mse=mean_squared_error(y_test, y_pred)
print("Mean Squared Error:",mse)
msep=mse/np.mean(y_pred)*100
print("Mean Squared Error Percentage:",msep,"%")
# Out:
# Mean Squared Error: 4.206564358473631
# Mean Squared Error Percentage: 7.60388012256278 %
